# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiaschnaible/OE_Unid4_Datos-climaticos-globales/blob/main/Analisis_de_datos_climaticos_globales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Configuración de identidad global
# !git config --global user.email "tu_email@ejemplo.com"
# !git config --global user.name "Tu Nombre Completo"

print("Identidad configurada correctamente")

from google.colab import userdata
import os

# Traemos el token que guardaste en la llave
token = userdata.get('GITHUB_TOKEN')
repo_url = f"https://{token}@github.com/nadiaschnaible/OE_Unid4_Datos-climaticos-globales.git"

# Clonamos el repositorio
# !git clone {repo_url}

# Entramos a la carpeta del repositorio
# %cd OE_Unid4_Datos-climaticos-globales
